# %%
with plt.xkcd():
    fig = plt.figure(figsize=(10,)*2)
    ax = fig.add_subplot(111)
    sns.despine()
    
#     ax.set_yticklabels(['','Cost-Benefit Analysis', 'Utility', 'Reliability',
#                         'Multi-objective trade-offs \n with posteriori preferences'])
    ax.set_yticklabels(['single measure\nof goodness', 'multi attribute\nutility', 'value diversity'])
    ax.set_yticks([1,2,3])
    ax.set_ylabel('Values', fontsize=20)
    
    ax.set_xticklabels(['certainty', 'risk', 
                        'deep uncertainty\nand ambiguity', 'unknown\nunknowns'])
    ax.set_xticks([1,2,3,4])
    ax.set_xlabel('Knowledge', fontsize=20)
    
    ax.tick_params(axis=u'both', which=u'both',length=0)
    
    ax.set_xlim(xmin=0, xmax=5)
    ax.set_ylim(ymin=0, ymax=4)
    
    ax.add_patch(mpl.patches.Rectangle((0.1,0.1), 2.2, 2.4, fill=False, color='r'))
    ax.text(1.15, 1.15, 'assumed by\nmany\nanalysis techniques\nsuch as CBA, MCDA, etc.', 
            ha='center', va='center', fontsize=15)
    
    ax.add_patch(mpl.patches.Rectangle((1.75,2.55), 1.75, 1.05, fill=False, color='b'))
    ax.text(2.625, 3, 'characteristic of\nmany real world problems', 
            ha='center', va='center', fontsize=15)


change_fontsize(fig, 15)
save_fig(fig, './figs/', 'conceptual diagram')
plt.show()

# %%
with plt.xkcd():
    fig = plt.figure(figsize=(10,)*2)
    ax = fig.add_subplot(111)
    sns.despine()
    
#     ax.set_yticklabels(['','Cost-Benefit Analysis', 'Utility', 'Reliability',
#                         'Multi-objective trade-offs \n with posteriori preferences'])
    ax.set_yticklabels(['single measure\nof goodness', 'multi attribute\nutility', 'value diversity'])
    ax.set_yticks([1,2,3])
    ax.set_ylabel('Values', fontsize=20)
    
    ax.set_xticklabels(['certainty', 'risk', 
                        'deep uncertainty\nand ambiguity', 'unknown\nunknowns'])
    ax.set_xticks([1,2,3,4])
    ax.set_xlabel('Knowledge', fontsize=20)
    
    ax.tick_params(axis=u'both', which=u'both',length=0)
    
    ax.set_xlim(xmin=0, xmax=5)
    ax.set_ylim(ymin=0, ymax=4)
    
    ax.add_patch(mpl.patches.Rectangle((0.1,0.1), 2.2, 2.4, fill=False, color='r'))
    ax.text(1.15, 1.15, 'assumed by\nmany\nanalysis techniques\nsuch as CBA, MCDA, etc.', 
            ha='center', va='center', fontsize=15)
    
    ax.add_patch(mpl.patches.Rectangle((1.75,2.55), 1.75, 1.05, fill=False, color='b'))
    ax.text(2.625, 3, 'Many Objective Robust\nDecision Making\nAdaptive pathways', 
            ha='center', va='center', fontsize=15)


change_fontsize(fig, 15)
save_fig(fig, './figs/', 'conceptual diagram2')
plt.show()

# %%
2.625
